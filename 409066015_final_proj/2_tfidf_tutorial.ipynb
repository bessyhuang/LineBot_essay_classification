# %% [markdown]
# <h1 align="center">中文資訊檢索（文件檢索）採用 TF-IDF 方法</h1>
# <h3 align="center">Chinese Document Retrieval with TF-IDF</h3>
# <hr>
# <pre>
# doc: 文件資料夾（純文字，utf-8）
# qry: 查詢字串
# </pre>

# %% [markdown]
# <hr>
# <h3>詞法分析，工具函數定義（刪除非中文的所有文字與符號）</h3>

# %%
# 詞法分析，工具函數定義（刪除非中文的所有文字與符號）

import re

def remove_non_chinese(line):
    # 消除英文文數字
    rule = re.compile('[a-zA-Z0-9]')
    line = rule.sub(' ', line)
    # 消除特殊符號（含部分全形符號）
    rule = re.compile('[’!"#$%&\'()*+,-./:;<=>?@，。?★、…【】《》？“”‘’！[\\]^_`{|}~\s]+')
    line = rule.sub(' ', line)
    # 消除不可見字碼
    rule = re.compile('[\001\002\003\004\005\006\007\x08\x09\x0a\x0b\x0c\x0d\x0e\x0f\x10\x11\x12\x13\x14\x15\x16\x17\x18\x19\x1a]+')
    line = rule.sub(' ', line)
    # 消除所有全形符號
    rule = re.compile('[^\u4e00-\u9fa5]')
    line = rule.sub(' ', line)
    return line

def remove_redundant_space(line):
    line = re.sub(' +', ' ', line)
    return line

# %% [markdown]
# <hr>
# <h3>詞法分析，載入 jieba 工具模組</h3>

# %%
# 詞法分析，載入 jieba 模組

import jieba

# 有必要的話載入常用辭典
jieba.set_dictionary('C:/Users/bessyhuang/Downloads/409066015_final_proj/dict.txt.big')
# 有必要的話載入專屬字典
jieba.load_userdict('C:/Users/bessyhuang/Downloads/409066015_final_proj/user.txt')
# Out:
# Building prefix dict from C:\Users\bessyhuang\Downloads\409066015_final_proj\dict.txt.big ...
# Loading model from cache C:\Users\BESSYH~1\AppData\Local\Temp\jieba.u813e690ac7055fdb60b803cf9566915f.cache
# Loading model cost 3.061 seconds.
# Prefix dict has been built successfully.

# %% [markdown]
# <hr>
# <h3>過濾無意義詞彙（stopwords，虛字與其它無意義詞彙）</h3>

# %%
# 過濾無意義詞彙（stopwords，虛字與其它無意義詞彙）

stopwords = [ '之', '乎', '者', '也', '的' ]

def remove_stopword(lst0):
    lst = []
    for x in lst0:
        if x not in stopwords:
            lst.append(x)
    return lst

# %% [markdown]
# <hr>
# <h3>詞法分析，函數定義</h3>

# %%
# 詞法分析，函數定義

def lexical_analyzer(txt):
    txt = remove_non_chinese(txt)
    txt = remove_redundant_space(txt)
    res = jieba.cut(txt)
    lst = [ x for x in res ]
    lst = remove_stopword(lst)
    doc = ' '.join(lst)
    doc = re.sub(' +', ' ', doc)
    return doc

# %% [markdown]
# <hr>
# <h3>整理 Corpus 資料格式</h3>

# %% [markdown]
# <hr>
# <h3>TF-IDF 文件檢索</h3>

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Using cached scikit_learn-0.23.1-cp37-cp37m-win_amd64.whl (6.8 MB)
# Collecting scipy>=0.19.1
#   Using cached scipy-1.4.1-cp37-cp37m-win_amd64.whl (30.9 MB)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Collecting joblib>=0.11
#   Using cached joblib-0.15.1-py3-none-any.whl (298 kB)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\bessyhuang\downloads\venv\lib\site-packages (from scikit-learn) (1.18.5)
# Installing collected packages: scipy, threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-0.15.1 scikit-learn-0.23.1 scipy-1.4.1 threadpoolctl-2.1.0

# %% [markdown]
# <hr>
# <h3 style="color:orange">『朱自清散文』語料的資料檢索平台建立（整合版）</h3>
# <pre>
# 語料來源：
# <a href="http://www.bwsk.net/mj/z/zhuziqing/index.html">http://www.bwsk.net/mj/z/zhuziqing/index.html</a>
# </pre>

# %%
# 『朱自清散文』語料的資料檢索平台建立（整合版）

# 詞法分析，工具函數定義（刪除非中文的所有文字與符號）

import re

def remove_non_chinese(line):
    # 消除英文文數字
    rule = re.compile('[a-zA-Z0-9]')
    line = rule.sub(' ', line)
    # 消除特殊符號（含部分全形符號）
    rule = re.compile('[’!"#$%&\'()*+,-./:;<=>?@，。?★、…【】《》？“”‘’！[\\]^_`{|}~\s]+')
    line = rule.sub(' ', line)
    # 消除不可見字碼
    rule = re.compile('[\001\002\003\004\005\006\007\x08\x09\x0a\x0b\x0c\x0d\x0e\x0f\x10\x11\x12\x13\x14\x15\x16\x17\x18\x19\x1a]+')
    line = rule.sub(' ', line)
    # 消除所有全形符號
    rule = re.compile('[^\u4e00-\u9fa5]')
    line = rule.sub(' ', line)
    return line

def remove_redundant_space(line):
    line = re.sub(' +', ' ', line)
    return line

# 詞法分析，載入 jieba 模組

import jieba

# 有必要的話載入常用辭典
jieba.set_dictionary('C:/Users/bessyhuang/Downloads/409066015_final_proj/dict.txt.big')
# 有必要的話載入專屬字典
jieba.load_userdict('C:/Users/bessyhuang/Downloads/409066015_final_proj/user.txt')

# 無意義詞彙過濾（stopwords，虛字與其它無意義詞彙）
stopwords = [ '之', '乎', '者', '也', '的' ]

def remove_stopword(lst0):
    lst = []
    for x in lst0:
        if x not in stopwords:
            lst.append(x)
    return lst

# 詞法分析，函數定義

def lexical_analyzer(txt):
    txt = remove_non_chinese(txt)
    txt = remove_redundant_space(txt)
    res = jieba.cut(txt)
    lst = [ x for x in res ]
    lst = remove_stopword(lst)
    doc = ' '.join(lst)
    doc = re.sub(' +', ' ', doc)
    return doc

# 整理 Corpus 資料格式

import glob
import pickle

files = glob.glob('C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF/*.txt')

corpus = dict()

for f in files:
    with open(f, 'r', encoding='utf-8') as fp:
        txt = fp.read()
#         print(txt)
    fp.close()
    corpus[f] = { 'name':f, 'txt':txt, 'doc':None }

# 儲存語料庫

for f in corpus:
    txt = corpus[f]['txt']
    doc = lexical_analyzer(txt)
    corpus[f]['doc'] = doc

with open('C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF/corpus_Paper_text_TFIDF.pkl', 'wb') as fp:
    pickle.dump(corpus, fp)
fp.close()
# Out:
# Building prefix dict from C:\Users\bessyhuang\Downloads\409066015_final_proj\dict.txt.big ...
# Loading model from cache C:\Users\BESSYH~1\AppData\Local\Temp\jieba.u813e690ac7055fdb60b803cf9566915f.cache
# Loading model cost 3.103 seconds.
# Prefix dict has been built successfully.

# %% [markdown]
# <hr>
# <h3 style="color:orange">測試</h3>

# %%
# 測試

# 載入語料庫
import pickle

with open('C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF/corpus_Paper_text_TFIDF.pkl', 'rb') as fp:
    corpus = pickle.load(fp)
fp.close()

# TF-IDF 文件檢索

from sklearn.feature_extraction.text import TfidfVectorizer

qry = '統計+迴歸'

vectorizer = TfidfVectorizer()

def cosine_sim(text1, text2):
    tfidf = vectorizer.fit_transform([text1, text2])
    return ((tfidf * tfidf.T).A)[0,1]

d = dict()
for f in corpus:
    text1 = lexical_analyzer(qry)
    text2 = corpus[f]['doc']
    c = cosine_sim(text1, text2)
    d[f] = c

# 字典排序（成為串列）
lst = sorted(d.items(), key=lambda x: x[1], reverse=True)

# 顯示排序結果
print('查詢：', qry)
for f, c in lst:
    t = '關連度：%12.10f，文章：%s' % (c, f)
    print(t)
# Out:
# 查詢： 統計+迴歸
# 關連度：0.1068515336，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\泌尿系統感染症門診醫療資源之研究.txt
# 關連度：0.0701803715，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\非常態資料遺失值插補法之研究.txt
# 關連度：0.0673894830，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\遺傳程式規劃為基的時間序列模型在金融市場之應用.txt
# 關連度：0.0658446983，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\住院消化系統疾病患者對醫療資源耗用之研究.txt
# 關連度：0.0647464155，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\高壓輸電線密度與兒童癌症發生率之流行病學研究.txt
# 關連度：0.0614007323，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\智慧型商業資料分析之研究.txt
# 關連度：0.0607534270，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\台日韓三國產業股價指數報酬連動及其對個股報酬的影響.txt
# 關連度：0.0607315856，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\利用CART分類與迴歸樹建立消費者信用貸款違約風險評估模型之研究-以國內A銀行為例.txt
# 關連度：0.0580057597，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\整合羅吉斯迴歸分析與類神經網路建構兩階段之財務危機預警模型.txt
# 關連度：0.0551304230，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\家庭氣氛、親子關係及同儕關係之研究－以苗栗市高中、職學生為例.txt
# 關連度：0.0527032043，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\應用平衡計分卡探討國軍基礎教育績效之評估－以國防大學為例.txt
# 關連度：0.0511386392，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\國際型股票基金之研究.txt
# 關連度：0.0437837288，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\運動賽會現場觀眾參與行為與企業贊助效益認知之研究—以第三季超級籃球聯賽為例.txt
# 關連度：0.0374936298，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\比較不同口腔護理方案對氣管內管留置病患口腔黏膜改變之成效.txt
# 關連度：0.0374734377，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\賭博犯罪因素之研究-以臺北縣為例.txt
# 關連度：0.0365474221，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\非營利組織捐款者忠誠度之分析研究--以某社會福利基金會兒童服務方案為例.txt
# 關連度：0.0334841222，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\沉默螺旋理論之實證研究以週休二日制為例.txt
# 關連度：0.0321242326，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\阻塞性睡眠呼吸中止症患者情緒狀態與疾病嚴重度的關聯：探討自主神經系統及嗜睡程度的中介影響.txt
# 關連度：0.0305123804，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\動能投資策略在台灣股市之應用.txt
# 關連度：0.0300700155，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\寧握護理對早產兒接受侵入性治療後生理性影響之研究.txt
# 關連度：0.0289387189，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\探討鬆弛訓練對外科加護病房術後病患急性疼痛及焦慮緩解之成效.txt
# 關連度：0.0277690167，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\臺北縣公立國民小學創新環境與教師教學創新行為之研究.txt
# 關連度：0.0269106286，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\新台幣利率交換買賣價差之實證研究.txt
# 關連度：0.0258054504，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\臺北市國民中學教師角色認同與組織公民行為關係之研究.txt
# 關連度：0.0255566034，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\體育場志工參與行為與參與態度之研究-以臺北縣立板橋體育場為例.txt
# 關連度：0.0248061709，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\資訊產品流通業-印表機行銷通路的研究.txt
# 關連度：0.0245522006，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\企業財務危機之預警－以KMVModel和現金流量之比較.txt
# 關連度：0.0245196459，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\台北縣國中健康與體育教師資訊素養及資訊科技融入教學之研究.txt
# 關連度：0.0241084505，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\桃園縣高中職軍訓教官角色行為與工作績效之研究.txt
# 關連度：0.0238048900，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\運動營隊參與者服務品質認知與滿意度之研究－以2006年兄弟象棒球冬令營為例.txt
# 關連度：0.0215904680，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\處置效果與報酬動能關係之探討.txt
# 關連度：0.0212511273，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\足球運動教練專業知識與技術能力之研究.txt
# 關連度：0.0210632791，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\利用溶劑和取代基效應微調經由釕氨吡啶錯合物之端點間電子轉移系統.txt
# 關連度：0.0202359420，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\台電公司營業區處技術人員核心職能辨識與職能表現關係之研究.txt
# 關連度：0.0201632824，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\電話詐欺犯罪特性之研究－以台北縣為例.txt
# 關連度：0.0199557472，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\高中體育班學生次級文化研究-以臺北縣縣立高中為例.txt
# 關連度：0.0199557472，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\女性護理人員之罹病風險及常見疾病之研究.txt
# 關連度：0.0195372523，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\台北市公立國民中學學校願景發展與教師工作士氣之關係研究.txt
# 關連度：0.0195208370，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\健康體適能俱樂部購買意願之影響因素.txt
# 關連度：0.0194990141，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\估計Gamma製程中干擾啟始時間之研究.txt
# 關連度：0.0185555032，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\領導行為與部屬忠誠-人治、法治企業文化脈絡之影響.txt
# 關連度：0.0179938155，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\觀光意象與體驗價值對行為意向之研究-以平溪鄉為例.txt
# 關連度：0.0176285935，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\2004年雅典奧運女子壘球選手不同投打習慣打擊能力與勝負之分析研究.txt
# 關連度：0.0162448021，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\台北縣市幼兒運動遊戲指導員工作價值觀、工作投入與工作倦怠之研究.txt
# 關連度：0.0159179514，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\個人轉寄網路連鎖信之影響因素研究.txt
# 關連度：0.0154099849，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\台灣男性時尚雜誌廣告與男性外貌形象研究.txt
# 關連度：0.0153352571，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\台北市高職學生升學壓力、因應方式與身心健康之研究.txt
# 關連度：0.0150368597，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\個人投資者股票重購行為再探.txt
# 關連度：0.0147931363，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\以ATP生物冷光方法預測盒餐微生物品質.txt
# 關連度：0.0147836323，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\大學生運動參與與性別角色關係之研究-以輔仁大學為例.txt
# 關連度：0.0147363854，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\三氧化二砷抑制小白鼠精蟲之分化及活性.txt
# 關連度：0.0145973172，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\桃園縣國民小學體育課實施游泳教學現況及阻礙因素之調查研究.txt
# 關連度：0.0142704396，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\國際觀光旅館外賣專櫃品牌延伸契合度對消費者行為意向之影響.txt
# 關連度：0.0141274383，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\影響線上購物顧客忠誠度因素之研究-以Yahoo!奇摩為例.txt
# 關連度：0.0140616146，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\台北市國民小學家長心目中理想校長條件之研究.txt
# 關連度：0.0140128462，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\台北市公立國民小學教師全球視野認知與影響因素之研究.txt
# 關連度：0.0137305235，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\國民小學九年一貫教學輔導團團隊凝聚力與團體層次組織公民行為關係之研究.txt
# 關連度：0.0134574374，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\迷信消費利益與成本之探討.txt
# 關連度：0.0133233897，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\旅遊網站服務品質對顧客關係品質及忠誠度影響之研究.txt
# 關連度：0.0128745306，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\人格特質、印象管理策略選擇與印象管理策略知覺之研究，以團體套裝旅遊中領隊-團員為例.txt
# 關連度：0.0126189631，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\棒球投手投球動作之運動學分析.txt
# 關連度：0.0125998157，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\台北縣新莊地區國中生運動行為及其影響因素之研究.txt
# 關連度：0.0124910263，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\未婚教保人員單身壓力、婚姻態度及生活滿意度之相關研究.txt
# 關連度：0.0124681805，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\台灣公司債發行信用價差影響變數研究.txt
# 關連度：0.0116599233，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\通路結構、交易關係與通路績效之研究以台灣塑橡膠機械業為例.txt
# 關連度：0.0113469095，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\台灣上市公司股權結構的決定因素.txt
# 關連度：0.0110538515，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\國民中學初任教師工作適應及其影響因素之研究.txt
# 關連度：0.0108119783，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\資源配置觀點之企業價值分析.txt
# 關連度：0.0107787051，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\桃園縣中等學校游泳教學實施現況之研究.txt
# 關連度：0.0105540879，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\染髮劑對防護手套之滲透評估.txt
# 關連度：0.0104992435，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\國民小學家長參與校務因素與類型之研究—以臺北縣為例.txt
# 關連度：0.0100502274，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\平衡計分卡於護理人員工作壓力上之應用.txt
# 關連度：0.0100146199，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\大學校院甲組桌球選手知覺教練領導行為、團隊凝聚力與成績表現之研究.txt
# 關連度：0.0096915287，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\雙薪家庭國小高年級學童知覺父母參與、共親職與家庭生活幸福感之相關研究.txt
# 關連度：0.0096384678，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\來台旅客參與觀光旅遊線之消費型態研究.txt
# 關連度：0.0095966409，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\家長參與幼兒入園準備及幼兒在幼兒園適應之相關研究.txt
# 關連度：0.0095451151，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\台北縣國民小學教師專業角色知覺與教師效能關係之研究.txt
# 關連度：0.0094469820，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\台灣中小型營造業創業成功因素之探討.txt
# 關連度：0.0093207256，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\國民中學訓導主任角色壓力,人際關係與壓力因應策略之研究.txt
# 關連度：0.0092455006，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\台北縣國民小學教師對親師衝突知覺與衝突管理策略之研究.txt
# 關連度：0.0089958780，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\棒球打擊動作動學之分析研究.txt
# 關連度：0.0085408441，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\服務人員外顯行為對顧客情緒、顧客滿意度及顧客忠誠影響之研究─以性別角色與人格特質為干擾變數.txt
# 關連度：0.0082194108，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\國民小學藏書票教育實施現況之研究-以臺北縣為例.txt
# 關連度：0.0078866642，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\工作團隊多元性、團隊衝突對團隊效能影響之研究—以團隊認同為干擾變項.txt
# 關連度：0.0075165806，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\國小教師知覺與外籍配偶家長親師互動及其子女學校生活適應之相關研究.txt
# 關連度：0.0055436309，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\健康焦慮特徵與情緒間的調節因素：探討健康認知評估、嚴謹性人格的作用.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\3-苯硫基-4-取代基丁二烯□的合成及應用1.2-二苯硫基-1.3-丁二烯□的合成及Diels-Alder反應.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\A、B型人格特質對工作特性與工作滿意度關係的影響.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\GPS產業分析暨企業價值管理之研究-以麗臺科技公司為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\KMV模型加計預期虧損的信用風險評等.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\LCOS背投影電視鏡頭設計.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\OFDM系統之指標協助通道估測法的研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\Opensource架構下數位版權管理之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\REITs與S&P500股票市場波動來源之分析與比較.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\SOA架構在供應鏈系統系統規劃發展模式之應用研究-以Q公司為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\VaR模型評估市場風險之個別風險有效性之實證研究－以權益證券商品為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\Xanthomonas屬植物病原細菌之檢測及分子類型區分方法之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\《唐詩歸》之詩學觀研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\《集韻》增收叶韻字字音研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\「出口」－海洋生物的碎形表現.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\一位多重障礙兒母親的生命處境：自我敘說探究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\上市審議委員會決議之因素及對IPOs績效之影響.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\上架費之經濟分析.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\不動產業競爭策略之研究-以東煒建設公司為例不動產業競爭策略之研究-以東煒建設公司為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\中世紀農民之形成.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\中小企業間非正式人際互動、社會資本與企業經營發展關係之初探.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\串列誤差修正型脈波寬度調整器在直流—直流降壓器的轉換.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\亨德密特第三號大提琴獨奏奏鳴曲作品編號25之分析與詮釋.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\人口內生、政府支出的不同融通方式與經濟成長.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\代理人協商排課系統研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\代言人式電視運動廣告體驗認知以消費者購買動機觀念影響之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\以B-spline為基底的複數座標旋轉方法來研究鈹原子的光游離.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\以end-Hall型離子源輔助蒸鍍硒化鋅薄膜之光學測量研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\以PU Epoxy複合材料製作PDLC之可行性研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\以V2O5或TiO2做為注入層材料用以提升有機電激發光二極體之發光特性之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\以Web-based介面進行範例式查詢生化代謝途徑查詢系統.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\以六氟化硫為工作氣體之end-Hall型離子源輔助熱蒸鍍氟化鎂紫外光薄膜研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\以學生-問題分析法診斷學生認知狀態之情境感知學習-以計算機概論教學為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\以平衡計分卡為基的研發部門績效評估指標之可行性研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\以影像為基礎之距離與面積量測系統.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\以本體論為基之情境感知服務推理.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\以現金流量觀點探討企業獲利能力.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\以自由現金流量折現法評估購併價值－以台新金購併彰化銀行為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\以銥金屬錯合物為三重態能量接收者之電激發光研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\以銪金屬錯合物為三重態能量接收者之電激發光研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\任意提前清償融資假設下股酬資產交換評價.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\企業併購過程中，IT權力移轉之因素分析.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\企業識別系統、體驗行銷對品牌形象關係之研究—以統一星巴克咖啡為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\企業資訊系統委外關鍵成功因素之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\企業運用智慧型代理人影響電子商務顧客信任之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\住院病人留置尿管盛行率及導尿管相關尿路感染之菌種與抗藥性分析.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\佛瑞鋼琴作品即興曲之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\併購訊號、成長相對價值與股價績效表現之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\使用單緣觸發數位振盪器之全數位式鎖相迴路.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\使用圖形化通行碼之使用者身份認證設計的研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\使用支持向量機於本國專利自動分類之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\使用直接適應性模糊類神經控制器於防鎖死煞車系統之動態滑差估測與控制.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\使用連續型馬可夫模型從事臉部表情辨識.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\使用隱藏式馬可夫模型從事頭部姿勢辨識.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\供應商與買方合作關係持續性影響因素之探討--以台灣紡織成衣業為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\保健食品之競爭策略-以特殊營養品為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\保單貼現證券化評價與風險分析.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\保養品廣告訴求對廣告效果影響之研究以性別認知和贈品類型為干擾.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\信用衍生性金融工具之探討.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\個人電腦動態電源管理有效休眠時間之量測與模型.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\先秦兩漢孔子形象演變之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\內線交易、監督與公司價值.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\全數位脈波寬度控制迴路使用兩階式延遲元件.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\公司治理對股權分置改革的影響.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\公視「文學劇」：影像美學、文化符碼與性別建構.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\六標準差在金融業的運用－以A銀行為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\具有輸入 輸出無漣波電流之模糊邏輯鋰離子電池等化控制器.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\函數體上連分數的性質.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\分散式雜湊法為基礎檔案分享策略.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF
txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\墨子與耶穌之愛的比較.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\壽險業顧客交叉購買意圖之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\夏目漱石作品『心』的研究-關於「家」.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\外來直接投資與地主國市場的管制政策.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\多方多元醫療資訊交換之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\多目標之單機排程研究-含總流程時間與提前完工件數.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\多目標流程式排程有效解之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\多目標重疊式流程系統之排程研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\多重模數盲蔽等化演算法在非正方形星狀圖正交振幅調變之分析.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\大學體育室服務品質滿意度之研究以萬能科技大學為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\大專院校資源教室輔導人員離職經驗之敘說性研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\大氣微粒中指紋化合物之調查研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\大陸地區金融風險之研究--兼述台資商業銀行登陸問題.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\奈米金氣體感測材料之線性溶合能量關係模式與圖形辨識之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\好禮多選一之適用情境分析.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\如何量計信用風險一個市場基礎模式的實證研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\媒體建構的台客幻想世界—以【兩代電力公司】為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\子女氣質、母親後設情緒理念與子女依附傾向的相關性研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\學好翻譯基本功：檢視台灣國中英語科參考書的課文中譯問題以第五冊康軒、南一、翰林、朗文版部分課文為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\宅配業車輛裝載規劃問題之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\定量化暫存記憶體的已排班資料流架構.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\家電雜訊對寬頻電力線通訊影響之量測.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\實體產業廠商運用網路自助服務之消費者使用意願研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\專業型獨立契約者的專案知識特性與顧客溝通策略配適對溝通品質影響之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\尋找纜線寬頻潛在客戶之研究~以A有線電視為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\小螢幕文本呈現方式與視窗尺寸對閱讀速率、理解率、閱讀效率、滿意度之效應研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\嵌入式遠端電子量測系統設計與建構.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\工作價值觀、個人倫理氣候知覺與倫理行為關係之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\巴爾托克第二號小提琴協奏曲之曲式分析與演奏詮釋.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\市場基礎的信用風險管理模型之實證研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\布拉姆斯六首鋼琴小品作品一一八之音樂風格與演奏探討.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\庫藏股交易與每股盈餘管理－購回數量與時點之影響.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\廣告訊息、廣告解讀與消費行為－以台灣十大連鎖兒童美語補教業電視廣告為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\廣義能量泛函之一階及二階變分.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\建構接納包容班級之行動研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\建立基層行政機關服務品質衡量模式-以臺北市內湖區公所為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\張愛玲小說中書寫服裝寫作策略的探討——以〈金鎖記〉和《怨女》為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\影響大學生課外輔導選擇行為因素研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\影響工作滿意度因素之研究－以某軍種聘雇人員為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\影響工程統包績效之因素－臺電配電自動化工程之個案研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\影響服裝產業銷售量預測之因素探討—以童裝為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\從「默觀」看東西文化交流與對話──十字若望與莊子的對談.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\從不同版本的比較探討李斯特《帕格尼尼第六號練習曲》之演奏詮釋.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\從人壽保險業保單製作探討企業創新採用策略之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\從司法權本質論司法院一元單軌制之改革趨勢--以大法官釋字第五三０號解釋為緣起.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\快速人頭追蹤演算法.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\愛的哲學--從柏拉圖的愛到亞里斯多德的友愛.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\慢跑與爬坡之地面反作用力分析研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\慢跑與爬坡對心跳率之影響.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\慢跑與爬坡步態常模之建立.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\應用B2B模型開發大陸市場之可行性研究-以TFT-LCD產業為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\應用BLOOMBERG系統評價可轉換公司債.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\應用XACML於家用網路安全策略之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\應用在財務預測上的混合式模糊類神經網路.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\應用平衡計分卡觀點於護理人員離職意願之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\應用文化演算法於多代理人系統之共同演化.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\應用模擬情境於ERP教育訓練之研究－使用服務導向架構.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\應用資料採礦技術探討臺灣地區企業技術創新結構之研究應用資料採礦技術探討臺灣地區企業技術創新結構之研究應用資料採礦技術探討台灣地區企業技術創新結構之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\應用遺傳演算法與動態模糊化調整策略於指數型基金商品設計之研究－以台灣50指數為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\成年子女的孝道責任與焦慮：親子關係與父母需求的影響.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\我因思愛成病-生命意義的追尋.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\我國女子籃球選手知覺教練領導行為與團隊凝聚力研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\扶養義務類型論之研究--以生活保持義務之論述為中心--.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\承銷方式,公司特性與IPO折價之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\抑斥現象與僭越界線：旻娜‧洛伊前衛詩學之精神分析學式閱讀.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\投資決策風格為基的最適投資組合之研究－交談式遺傳演算法之應用.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\捷運站週邊社區街道人行環境改善之探討及設計--以新莊中華路一段為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\採訪時刻記者情緒展現之探索.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\探討企業採用資訊科技基礎架構庫因素之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\探討兒童與成人對於疾病病因和預防之概念.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\探討負面口碑傳播與消費者轉換意願之關係.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\控制流程與資料流程結構的快取效能.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\提升免疫調節的營養補充品--以紫錐花為例(綜論).txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\擔保債權憑證之評價-FitchVECTOR模型與GaussianCopula法之應用與比較.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\改良式預測搜尋區域演算法之快速區塊移動估計.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\教練轉型領導行為影響選手組織承諾與選手滿意度之研究～以94學年大專籃球聯賽第二級男子籃球選手為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\教育型態與所得不均度.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\整合情境資訊之多維度推薦環境.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\整合行銷傳播訊息一致性之認知反應與記憶效果初探.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\數位時代有線電視產業之價值管理.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\數位相機產業之競爭策略研究-以個案公司品牌行銷為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\數位電視與手機電視地面並行廣播之頭端系統建構.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\新巴塞爾資本協定下信用衍生性商品風險抵減之探討.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\新群體盲目多使用者偵測器在多通道路徑的直接序列分碼多重接取系統.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\方以智易學形上思想研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\旅行業顧客交叉購買意圖之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\日台共學制度之研究-以對台灣人的影響為中心(1922-1937).txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\普瑞德－威利氏症候群（Prader-Willisyndrome）病患家屬照護經驗之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\智慧型Ridit分析輔助系統之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\智慧型代理人程式碼相似度偵測系統.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\智慧型企業併購決策評估模式之研究–以某電子科技公司為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\智慧型保全資源與監視系統整合配置之研究-以台灣高鐵台中段為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\有機發光材料-奈米片層矽土 PVK複合材料系統之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\有關拉普拉斯變換與積分餘弦函數之逼近理論的研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\服務創新、情緒體驗與忠誠意圖之關係－以主題餐廳為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\期貨結算系統SPAN之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\未公開發行公司財務危機預警模型.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\未遂行為可罰性之研究-以不法為中心.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\本國銀行經營績效研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\李克特量表分數轉換之研究—以憂鬱情緒量表為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\松下耕女聲合唱作品《愛之精選》之分析與詮釋.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\柔道基層選手訓練站運作現況調查之研究—以台北縣市為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\校園潛伏性結核病感染篩檢之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\梅子再製酒之感官特性研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\標的產品行銷組合決策模式之廣告預算分配及訂價之研究－以臺灣茶類產品為例.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\機會發現與基因工程技術在遺傳演算法演化績效改良之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\機構投資人影響個人投資者群聚行為之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\權益交易誘因、分析師預測引導與盈餘管理之關係.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\次線性泛函之平滑性與嚴格凸性的Asplund平均化.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\比較五種流動性定義在台灣公債殖利率曲線之配適.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\汽車用安全氣囊布料之專利及材料分析.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF
txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\高速Baugh-Wooley乘法器電路使用歪斜容忍技術.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\高雄市國民中學九年一貫健康與體育學習領域課程實施現況及教師研習需求之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\高齡犯罪之概念與處遇相關問題之探討.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\魚與熊掌可兼得嗎？新聞記者工作與非工作領域間角色衝突研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\黃季剛先生說文學之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\點對點網路資訊搜尋之研究.txt
# 關連度：0.0000000000，文章：C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\點帶石斑抗黏液病毒與免疫球蛋白重鏈基因在胚胎期之表現.txt

# %%
# !pip install flask
# !pip install line-bot-sdk
# Out:
# Collecting flask
#   Using cached Flask-1.1.2-py2.py3-none-any.whl (94 kB)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\bessyhuang\downloads\venv\lib\site-packages (from flask) (2.11.2)
# Collecting Werkzeug>=0.15
#   Using cached Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting itsdangerous>=0.24
#   Using cached itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting click>=5.1
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\bessyhuang\downloads\venv\lib\site-packages (from Jinja2>=2.10.1->flask) (1.1.1)
# Installing collected packages: Werkzeug, itsdangerous, click, flask
# Successfully installed Werkzeug-1.0.1 click-7.1.2 flask-1.1.2 itsdangerous-1.1.0
# Collecting line-bot-sdk
#   Using cached line_bot_sdk-1.16.0-py2.py3-none-any.whl (59 kB)
# Collecting future
#   Using cached future-0.18.2.tar.gz (829 kB)
# Collecting requests>=2.0
#   Using cached requests-2.23.0-py2.py3-none-any.whl (58 kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Using cached urllib3-1.25.9-py2.py3-none-any.whl (126 kB)
# Collecting idna<3,>=2.5
#   Using cached idna-2.9-py2.py3-none-any.whl (58 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2020.4.5.2-py2.py3-none-any.whl (157 kB)
# Collecting chardet<4,>=3.0.2
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Using legacy setup.py install for future, since package 'wheel' is not installed.
# Installing collected packages: future, urllib3, idna, certifi, chardet, requests, line-bot-sdk
#     Running setup.py install for future: started
#     Running setup.py install for future: finished with status 'done'
# Successfully installed certifi-2020.4.5.2 chardet-3.0.4 future-0.18.2 idna-2.9 line-bot-sdk-1.16.0 requests-2.23.0 urllib3-1.25.9

# %%
import linebot
print(linebot.__version__)
# Out:
# 1.16.0

# %%
# 官方說明提供 LineBot 範例（使用 Flask提供服務）

from flask import Flask, request, abort
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle
import re
import jieba
import random

# 有必要的話載入常用辭典
jieba.set_dictionary('C:/Users/bessyhuang/Downloads/409066015_final_proj/dict.txt.big')
# 有必要的話載入專屬字典
jieba.load_userdict('C:/Users/bessyhuang/Downloads/409066015_final_proj/user.txt')

from linebot import (
    LineBotApi, WebhookHandler
)
from linebot.exceptions import (
    InvalidSignatureError
)
from linebot.models import (
    MessageEvent, TextMessage, TextSendMessage, ImageSendMessage
)
from linebot.models import (
    BubbleContainer,
    ImageComponent,
    URIAction,
    BoxComponent,
    TextComponent,
    ButtonComponent,
    FlexSendMessage
)

app = Flask(__name__)

# line_bot_api = LineBotApi('YOUR_CHANNEL_ACCESS_TOKEN')
# handler = WebhookHandler('YOUR_CHANNEL_SECRET')

# 設定 Channel (Bot) 的基本認證資訊
secret = 'c4c624df3022f8ad74b71f08343d73f6'
token = '0utYwlzRd24Y6UySwG/DplOvYcI+eIcTZFdQ77tF8E2vtQkw3sKsqbycIu25lu/8y3cugCBxb2ZSk35+Ar2ThobHmlwq62ZWSOJs1VajHia5nD4edyJFcEWpwUYM+hdivPmsdrg9JAWujcTWoNgN5wdB04t89/1O/w1cDnyilFU='
line_bot_api = LineBotApi(token)
handler = WebhookHandler(secret)

@app.route("/callback", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        print("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'


# 加入文字訊息處理程序
@handler.add(MessageEvent, message=TextMessage)
def handle_message(event):
    bot_reply(event)

stopwords = [ '之', '乎', '者', '也', '的' ]
def remove_stopword(lst0):
    lst = []
    for x in lst0:
        if x not in stopwords:
            lst.append(x)
    return lst

def remove_non_chinese(line):
    # 消除英文文數字
    rule = re.compile('[a-zA-Z0-9]')
    line = rule.sub(' ', line)
    # 消除特殊符號（含部分全形符號）
    rule = re.compile('[’!"#$%&\'()*+,-./:;<=>?@，。?★、…【】《》？“”‘’！[\\]^_`{|}~\s]+')
    line = rule.sub(' ', line)
    # 消除不可見字碼
    rule = re.compile('[\001\002\003\004\005\006\007\x08\x09\x0a\x0b\x0c\x0d\x0e\x0f\x10\x11\x12\x13\x14\x15\x16\x17\x18\x19\x1a]+')
    line = rule.sub(' ', line)
    # 消除所有全形符號
    rule = re.compile('[^\u4e00-\u9fa5]')
    line = rule.sub(' ', line)
    return line

def remove_redundant_space(line):
    line = re.sub(' +', ' ', line)
    return line

def lexical_analyzer(txt):
    txt = remove_non_chinese(txt)
    txt = remove_redundant_space(txt)
    res = jieba.cut(txt)
    lst = [ x for x in res ]
    lst = remove_stopword(lst)
    doc = ' '.join(lst)
    doc = re.sub(' +', ' ', doc)
    return doc

vectorizer = TfidfVectorizer()

def cosine_sim(text1, text2):
    tfidf = vectorizer.fit_transform([text1, text2])
    return ((tfidf * tfidf.T).A)[0,1]

# 訊息回覆函數定義
def bot_reply(event):
    uid = event.source.user_id
    msg = event.message.text #'統計+迴歸'
    if ('wordcloud' == msg):
        pic_list = ['https://i.imgur.com/hnFjxlk.png', 'https://i.imgur.com/5xR21Hq.png', 'https://i.imgur.com/MK26O5a.png', 
                    'https://i.imgur.com/eTpaLL0.png', 'https://i.imgur.com/ev2hS9P.png', 'https://i.imgur.com/RrwjQ0L.png', 'https://i.imgur.com/8qKiROY.png',
                    'https://i.imgur.com/7cbI5eL.png', 'https://i.imgur.com/OPHKprB.png', 'https://i.imgur.com/5rIcuUH.png', 'https://i.imgur.com/Wqcaziu.png',
                    'https://i.imgur.com/EU0X0I5.png', 'https://i.imgur.com/JGPowbw.png', 'https://i.imgur.com/oO20X3z.png', 'https://i.imgur.com/wKmlZLs.png',
                    'https://i.imgur.com/y5Kjowj.png', 'https://i.imgur.com/oTaGfCi.png', 'https://i.imgur.com/SE26CZw.png', 'https://i.imgur.com/g4nEA7d.png',
                    'https://i.imgur.com/1p8mZok.png', 'https://i.imgur.com/2GPUbwu.png', 'https://i.imgur.com/RmuSSmp.png', 'https://i.imgur.com/bFMGvt8.png',
                    'https://i.imgur.com/AIQo0La.png', 'https://i.imgur.com/dPXAbod.png', 'https://i.imgur.com/rubhRyB.png', 'https://i.imgur.com/nii6NZc.png',
                    'https://i.imgur.com/62RPikd.png', 'https://i.imgur.com/oHbjFwC.png', 'https://i.imgur.com/x72LD83.png', 'https://i.imgur.com/LKoqiUU.png',
                    'https://i.imgur.com/iNSanob.png', 'https://i.imgur.com/26fvWil.png', 'https://i.imgur.com/UdC8PGR.png'
        ]
        index = random.randint(0, len(pic_list) - 1)

        wordcloud_msg = ImageSendMessage(
            original_content_url=pic_list[index]+'.png',
            preview_image_url=pic_list[index]+'.png'
        )
        # 訊息發出
        line_bot_api.reply_message(event.reply_token, wordcloud_msg)
    elif ('category' == msg):
        # 建立 Flex 傳送訊息
            bubble = BubbleContainer(
                direction = 'ltr',
                hero = ImageComponent(
                    url='https://imgur.com/N04O3Tv.png',
                    size='full',
                    aspect_ratio='4:3', # one of 1:1, 2:1, 3:1, 16:9, 4:3, ...
                    aspect_mode='fit', # cover, fit
                    action=URIAction(uri='https://imgur.com/N04O3Tv.png', label='Flex')
                ),
                body = BoxComponent(
                    layout='vertical',
                    contents=[
                        TextComponent(text='碩博士論文數量的類別分布', weight='bold'),
                        TextComponent(text='A 一般商業學類 	論文篇數： 2'),
                        TextComponent(text='B 一般大眾傳播學類 	論文篇數： 12'),
                        TextComponent(text='C 一般法律學類 	論文篇數： 4'),
                        TextComponent(text='D 中國語文學類 	論文篇數： 7'),
                        TextComponent(text='E 企業管理學類 	論文篇數： 35'),
                        TextComponent(text='F 兒童保育學類 	論文篇數： 10'),
                        TextComponent(text='G 公共衛生學類 	論文篇數： 6'),
                        TextComponent(text='H 其他商業及管理學類 	論文篇數： 15'),
                        TextComponent(text='I 化學學類 	論文篇數： 12'),
                        TextComponent(text='J 哲學學類 	論文篇數： 6'),
                        TextComponent(text='K 外國語文學類 	論文篇數： 11'),
                        TextComponent(text='L 宗教學類 	論文篇數： 2'),
                        TextComponent(text='M 專業科目教育學類 	論文篇數： 28'),
                        TextComponent(text='N 心理學類 	論文篇數： 9'),
                        TextComponent(text='O 教育行政學類 	論文篇數： 17'),
                        TextComponent(text='P 數學學類 	論文篇數： 6'),
                        TextComponent(text='Q 景觀設計學類 	論文篇數： 1'),
                        TextComponent(text='R 會計學類 	論文篇數： 3'),
                        TextComponent(text='S 服飾學類 	論文篇數： 10'),
                        TextComponent(text='T 歷史學類 	論文篇數： 2'),
                        TextComponent(text='U 營養學類 	論文篇數： 7'),
                        TextComponent(text='V 物理學類 	論文篇數： 6'),
                        TextComponent(text='W 生物學類 	論文篇數： 7'),
                        TextComponent(text='X 社會工作學類 	論文篇數： 3'),
                        TextComponent(text='Y 統計學類 	論文篇數： 35'),
                        TextComponent(text='Z 經濟學類 	論文篇數： 7'),
                        TextComponent(text='a 美術學類 	論文篇數： 2'),
                        TextComponent(text='b 翻譯學類 	論文篇數： 1'),
                        TextComponent(text='c 護理學類 	論文篇數： 5'),
                        TextComponent(text='d 財務金融學類 	論文篇數： 44'),
                        TextComponent(text='e 電算機一般學類 	論文篇數： 42'),
                        TextComponent(text='f 電資工程學類 	論文篇數： 49'),
                        TextComponent(text='g 音樂學類 	論文篇數： 17'),
                        TextComponent(text='h 餐旅服務學類 	論文篇數： 7')
                    ]
                )
            )
            flx = FlexSendMessage(alt_text='This is my flex message...', contents=bubble)
            line_bot_api.push_message(uid, flx)
    else:
        with open('C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF/corpus_Paper_text_TFIDF.pkl', 'rb') as fp:
            corpus = pickle.load(fp)
        fp.close()

        # TF-IDF 文件檢索
        d = dict()
        for f in corpus:
            text1 = lexical_analyzer(msg)
            text2 = corpus[f]['doc']
            c = cosine_sim(text1, text2)
            d[f] = c

        # 字典排序（成為串列）
        lst = sorted(d.items(), key=lambda x: x[1], reverse=True)
        # 顯示排序結果
        print('查詢：', msg)
        for f, c in lst:
            t = '關連度：%12.10f，文章：%s' % (c, f)

        txt = lst[:5] #('...', 0.000)
        new_txt_lst = ''
        for i in range(0, len(txt)):
            print(txt[i])
            paper_msg = txt[i][0]   #msg = 'C:/Users/bessyhuang/Downloads/python/Paper_text_TFIDF\遺傳程式規劃為基的時間序列模型在金融市場之應用.txt'
            paper_msg = paper_msg.replace('/', '//')
            paper_msg = paper_msg.replace('\\', '//')
            paper_msg = paper_msg.replace('C://Users//bessyhuang//Downloads//409066015_final_proj//Paper_text_TFIDF//', '').replace('.txt', '')
            paper_probability = txt[i][1]
            msg = '關連度：%12.10f，文章：%s \n' % (paper_probability, paper_msg) 
            print(msg)
            new_txt_lst += msg
        line_bot_api.reply_message(event.reply_token, TextSendMessage(text=new_txt_lst))
    return

if __name__ == "__main__":
    app.run()
# Out:
# Building prefix dict from C:\Users\bessyhuang\Downloads\409066015_final_proj\dict.txt.big ...
# Loading model from cache C:\Users\BESSYH~1\AppData\Local\Temp\jieba.u813e690ac7055fdb60b803cf9566915f.cache
# Loading model cost 2.976 seconds.
# Prefix dict has been built successfully.
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 查詢： 數學
# ('C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\\選擇權上的脈衝.txt', 0.11284368452965554)
# 關連度：0.1128436845，文章：選擇權上的脈衝
#
# ('C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\\宅配業車輛裝載規劃問題之研究.txt', 0.0370142574104793)
# 關連度：0.0370142574，文章：宅配業車輛裝載規劃問題之研究
#
# ('C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\\災後重建資源規劃智慧型決策模式之研究.txt', 0.029379446642787174)
# 關連度：0.0293794466，文章：災後重建資源規劃智慧型決策模式之研究
#
# ('C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\\多重模數盲蔽等化演算法在非正方形星狀圖正交振幅調變之分析.txt', 0.027375700935528494)
# 關連度：0.0273757009，文章：多重模數盲蔽等化演算法在非正方形星狀圖正交振幅調變之分析
#
# ('C:/Users/bessyhuang/Downloads/409066015_final_proj/Paper_text_TFIDF\\非金融機構市場風險管理.txt', 0.021645433660397017)
# 關連度：0.0216454337，文章：非金融機構市場風險管理
# 127.0.0.1 - - [16/Jun/2020 19:03:18] "POST /callback HTTP/1.1" 200 -
